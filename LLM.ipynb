# %%
import pandas as pd

# %%
import pandas as pd

#  text conversation to dataframe for further process
conversation = [
    "customer: rendle",
    "agent: hello good afternoon so",
    "customer: yes we're speaking",
    "agent: sir my name is amiss and i am your support coordinator with the resources and we wanted to check two things about your business with you if it is the right time sir",
    "customer: uh yeah yeah it's one thing i think there's no issue with that there's a base",
    "agent: okay sorry but actually i want to",
    "customer: yeah",
    "agent: ask for some questions related to your business",
    "customer: yeah",
    "agent: yes sir actually i have noticed a decline in your business transactions with regard to over the past month i would like to confirm",
    "customer: yes yes yes",
    "agent: yes i would like to something",
    "customer: because we we are involved you know in a in a specific tourism related business you know like flying business we are involved with paragliding okay",
    "agent: oh",
    "customer: so uh i just started it last year before that we were with pay",
    "agent: okay some",
    "customer: pay then somehow the you know pay you got resolved and also that was also working but now i'm planning to shift it entirely to raise your pay itself",
    "customer: because i find the platform is much better you know than uh e u",
    "customer: the next part is that we we are a seasonal business okay so most probably by october fifteenth we generally close actually it doesn't fly in the winters",
    "customer: then it again starts in myanmar sepulchre so so we take you know payments on site payments and also it's used there",
    "agent: okay sir so as you said it is the business long period so what are your peak months",
    "customer: ah i think peak months are maybe around may june july that's the peak you know in",
    "agent: okay sir i understand sir as you said you are sir you are totally shifting to the razor pay sir we look forward to giving you the best experience on razor pay itself sir we believe that utilizing our service for your entire payment facilitation process",
    "customer: yes yes yes",
    "agent: would be ideal and would also simply require account reconciliation",
    "customer: exactly that it will be greatly simplifying right now you know looking after two accounts you know looking out here in pay you also in razor also then it becomes a lot of accounting difficulties so but basically i'm planning to shift it out entirely to you know pay ya sorry raiser pay itself",
    "customer: so not an issue at all and that's",
    "agent: thank you so much",
    "customer: because i find that your settlement time period you know payments you know it's all",
    "customer: all very clear transfer and on time the reason why i come to pay was because you know pay you money used to you know deduct uh you know money from the clients and then you know the transfer period to our accounts is extremely high you know and uh you have to go back several months you know raising you know",
    "agent: as i understand",
    "customer: business queries and all making complaints and to get your own money back that was a very painful exercise so now i think it's all very simplified in research preferring that actually right now",
    "customer: it's a good news for yourself",
    "agent: he said finish",
    "customer: for reservation",
    "agent: yes provide you the better experience on days of itself so that you don't need to ship anywhere",
    "customer: yes yes yes sure sure sure",
    "agent: yes right",
    "customer: thank you and thank you",
    "agent: there is one more question as you accept the payments you currently are accepting and through what is your u p i share",
    "customer: u p s i yet to see actually that's quite high actually rather than cards or something",
    "agent: yes i'm",
    "customer: because i have to check it out in detail so i've not gone through that but recently i had actually checked their",
    "customer: sixty percent of the payments are mostly coming from u",
    "agent: ok so listen",
    "customer: you know yeah yeah yeah that that was there but i think we'll have to check that out but there's a lot of card payments and all what i mean the biggest amount you know",
    "agent: okay sir",
    "customer: the movie done by",
    "agent: mm yes i understand so",
    "customer: chairman jim",
    "agent: so is there anything else i can help you with sir",
    "customer: oh no no not at the moment okay",
    "agent: i'll be sorry",
    "customer: thank you thank you for the attention",
    "agent: service yes the reserve cares about all its customers in the meanwhile if you have any other concern or queries then you can definitely raise your ticket and thank you so much for giving your time sir have a nice day",
    "customer: definitely ma'am definitely thank you",
    "agent: thank you so much"
]

# Initialize empty lists for agent and customer messages
agent_messages = []
customer_messages = []

# Split the conversation into agent and customer messages
for message in conversation:
    if message.startswith("agent:"):
        agent_messages.append(message.replace("agent:", "").strip())
    elif message.startswith("customer:"):
        customer_messages.append(message.replace("customer:", "").strip())

# Ensure equal lengths for agent and customer messages
min_length = min(len(agent_messages), len(customer_messages))
agent_messages = agent_messages[:min_length]
customer_messages = customer_messages[:min_length]

# Create a pandas DataFrame
df = pd.DataFrame({'Agent': agent_messages, 'Customer': customer_messages})
df.to_csv('conversation_data2.csv', index=False)

# %%
df
# Out:
#                                                                                                                                                                                                                                                            Agent  \
# 0                                                                                                                                                                                                                                        hello good afternoon so
# 1                                                                                           sir my name is amiss and i am your support coordinator with the resources and we wanted to check two things about your business with you if it is the right time sir
# ...

# %%
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv("conversation_data2.csv",encoding='latin')

# %%
#!pip install -r requirements.txt

# %%
from langchain.document_loaders import CSVLoader
obj = CSVLoader(file_path="conversation_data2.csv",source_column='Agent')
data  = obj.load()

# %%
from langchain.llms import GooglePalm
#!pip install google-generativeai

api_key = "AIzaSyCL0xKiTPVLTNrFfIoYO8bf_rO8yMrf6tM"
llmG = GooglePalm(google_api_key = api_key , temperature = 0.7)

# %%
o_api_key="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"

# %%
# from langchain.llms import OpenAI

# llmO = OpenAI(openai_api_key=o_api_key,temperature=0.7)

# %%
#!pip install OpenAI
#!pip install --upgrade openai langchain

# %%
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import FAISS

embeddings_model = OpenAIEmbeddings(openai_api_key=o_api_key)
# text = "This is a test document."
# query_result = embeddings_model.embed_query(text)

vector_database = FAISS.from_documents(documents=data, embedding=embeddings_model)

# %%
retrive_obj = vector_database.as_retriever()
# r_docs = retrive_obj.get_relevant_documents("")
# r_docs

# %%
from langchain.prompts import PromptTemplate
prompt_template = """Given the following context and a question, generate an answer based on this context only.
In the answer try to provide as much text as possible from "response" section in the source document context without making much changes.
If the answer is not found in the context, kindly state "I don't know." Don't try to make up an answer.

CONTEXT: {context}

QUESTION: {question}"""

PROMPT = PromptTemplate(template=prompt_template, input_variables=["context", "question"])

chain_type_kwargs = {"prompt": PROMPT}

# %%
from langchain.chains import RetrievalQA
chain = RetrievalQA.from_chain_type(llm = llmG , 
                                    chain_type = "stuff"
                                    , retriever = retrive_obj , 
                                    input_key = "query" ,
                                    return_source_documents=True,
                                    chain_type_kwargs = {"prompt":PROMPT})

# %%
chain("yes sir actually i have noticed a decline in your business transactions with regard to over the past month i would like to confirm")
# Out:
# {'query': 'yes sir actually i have noticed a decline in your business transactions with regard to over the past month i would like to confirm',
#  'result': 'yeah',
#  'source_documents': [Document(page_content='Agent: yes sir actually i have noticed a decline in your business transactions with regard to over the past month i would like to confirm\nCustomer: yeah', metadata={'source': 'yes sir actually i have noticed a decline in your business transactions with regard to over the past month i would like to confirm', 'row': 4}),
#   Document(page_content="Agent: okay sir so as you said it is the business long period so what are your peak months\nCustomer: pay then somehow the you know pay you got resolved and also that was also working but now i'm planning to shift it entirely to raise your pay itself", metadata={'source': 'okay sir so as you said it is the business long period so what are your peak months', 'row': 8}),
# ...
